# %% [markdown]
# # Search and Export ECOSTRESS and EMIT Granules
#
# Based on the type and location of the data you want to collect, you can choose whether to get the "Tiled" or "Swath" land surface temperature and emissivity.
#
# The data that will be downloaded can be altered in the "Filter by file types" section of each code block.
#
# Tiled data is best suited for large, regularly gridded datasets where you want to efficently manage and process individual sections of the overall data. Whereas swath data is used to represent data collected along a specific path or track, often with varying resolution and coverage.

# %% [markdown]
# ## Search for Tiled Land Surface Temperature and Emissivity

# %%
#This code is to search for export various site granules at one time. Granules will be downloaded to a .txt file 
import os
import pandas as pd
import geopandas as gpd
import earthaccess

def process_site(site_name, polygon_path, out_dir, start_date="2024-01-01", end_date="2025-07-23"):
    """
    For a given site:
    - Loads the polygon
    - Searches ECOSTRESS and EMIT granules
    - Filters to relevant file types
    - Saves result URLs in a .txt and .csv file in the site-specific folder
    """
    # Load polygon
    poly = gpd.read_file(polygon_path)
    minx, miny, maxx, maxy = poly.total_bounds

    # Set up temporal range and concept IDs
    date_range = (start_date, end_date)
    concept_ids = [
        "C2408750690-LPCLOUD",  # EMIT L2A Reflectance Tiled
        "C2076090826-LPCLOUD"   # ECOSTRESS L2T LST/Emissivity Tiled
    ]

    # Search for granules in bounding box
    print(f" Date range searched: {start_date} to {end_date}")

    results = earthaccess.search_data(
        concept_id=concept_ids,
        bounding_box=(minx, miny, maxx, maxy),
        temporal=date_range,
        cloud_hosted=True
    )

    # Split ECOSTRESS and EMIT
    emit_granules = [g for g in results if g["umm"]["CollectionReference"]["ShortName"] == "EMITL2ARFL"]
    eco_granules  = [g for g in results if g["umm"]["CollectionReference"]["ShortName"] == "ECO_L2T_LSTE"]

    # Filter by file types
    desired_ecostress_assets = ['_LST.tif', '_QC.tif', '_cloud.tif']
    desired_emit_extensions = ['.nc']

    filtered_urls = []

    for g in eco_granules:
        for url in g.data_links(access="https"):
            if any(url.endswith(tag) for tag in desired_ecostress_assets):
                filtered_urls.append(url)

    for g in emit_granules:
        for url in g.data_links(access="https"):
            if any(url.endswith(ext) for ext in desired_emit_extensions):
                filtered_urls.append(url)

    # Make output folder if needed
    os.makedirs(out_dir, exist_ok=True)

    # Save to .txt
    txt_path = os.path.join(out_dir, f"{site_name}_granules.txt")
    with open(txt_path, "w") as f:
        for url in filtered_urls:
            f.write(url + "\n")

    print(f"🔍 {site_name} search:")
    print(f"   ECOSTRESS granules found: {len(eco_granules)}")
    print(f"   EMIT granules found:     {len(emit_granules)}")
    print(f"   Total granules found:     {len(emit_granules + eco_granules)}")

    # Save to .csv
    df = pd.DataFrame({'url': filtered_urls})
    df.to_csv(os.path.join(out_dir, f"{site_name}_granules.csv"), index=False)

    print(f"✅ {site_name}: Found {len(filtered_urls)} granule files. Saved to {out_dir}")

    return eco_granules, emit_granules

# %% [markdown]
# ## Search for Swath Land Surface Temperature and Emissivity

# %%
#This code is to search for export various site granules at one time. Granules will be downloaded to a .txt file 
import os
import pandas as pd
import geopandas as gpd
import earthaccess

def process_site(site_name, polygon_path, out_dir, start_date="2025-04-01", end_date="2025-06-30"):
    """
    For a given site:
    - Loads the polygon
    - Searches ECOSTRESS and EMIT granules
    - Filters to relevant file types
    - Saves result URLs in a .txt and .csv file in the site-specific folder
    """
    # Load polygon
    poly = gpd.read_file(polygon_path)
    minx, miny, maxx, maxy = poly.total_bounds

    # Set up temporal range and concept IDs 
    date_range = (start_date, end_date)
    concept_ids = [
        "C2408750690-LPCLOUD",   # EMIT L2A Reflectance (swath)
        "C2076114664-LPCLOUD"    # ECOSTRESS L2 Swath LSTE
    ]

    # Search for granules in bounding box
    print(f" Date range searched: {start_date} to {end_date}")

    swath_results = earthaccess.search_data(
        concept_id=concept_ids,
        bounding_box=(minx, miny, maxx, maxy),
        temporal=(start_date, end_date),
        cloud_hosted=True
    )

    print(f"Total SWATH granules found: {len(swath_results)}")


    # Split ECOSTRESS and EMIT
    emit_granules = [g for g in swath_results if g["umm"]["CollectionReference"]["ShortName"].startswith("EMIT")]
    eco_granules  = [g for g in swath_results if g["umm"]["CollectionReference"]["ShortName"].startswith("ECO_L2")]


    # Filter by file types
    desired_swath_ecostress_extensions = ['.h5', '.nc', '.hdf5']
    desired_swath_emit_extensions = ['.nc']

    filtered_urls = []

    for g in eco_granules:
        for url in g.data_links(access="https"):
            if any(url.endswith(tag) for tag in desired_swath_ecostress_extensions):
                filtered_urls.append(url)

    for g in emit_granules:
        for url in g.data_links(access="https"):
            if any(url.endswith(ext) for ext in desired_swath_emit_extensions):
                filtered_urls.append(url)

    # Make output folder if needed
    os.makedirs(out_dir, exist_ok=True)

    # Save to .txt
    txt_path = os.path.join(out_dir, f"{site_name}_granules.csv")
    with open(txt_path, "w") as f:
        for url in filtered_urls:
            f.write(url + "\n")

    print(f"🔍 {site_name} search:")
    print(f"   ECOSTRESS granules found: {len(eco_granules)}")
    print(f"   EMIT granules found:     {len(emit_granules)}")
    print(f"   Total granules found:     {len(emit_granules + eco_granules)}")

    # # Save to .csv
    # df = pd.DataFrame({'url': filtered_urls})
    # df.to_csv(os.path.join(out_dir, f"{site_name}swath_granules.csv"), index=False)

    # print(f"✅ {site_name}: Found {len(filtered_urls)} granule files. Saved to {out_dir}")

    return eco_granules, emit_granules

# %%
# Update these with your actual file paths
process_site(
    site_name="LCDM",
    polygon_path="/Users/kylamonique/Desktop/JPLFiles/SpectralEvolution/GIS/Waypoints/LCDMQuadrat.geojson",
    out_dir="/Users/kylamonique/Desktop/JPLFiles/data/LCDM"
)

process_site(
    site_name="SD",
    polygon_path="/Users/kylamonique/Desktop/JPLFiles/SpectralEvolution/GIS/Waypoints/SDQuadrat.geojson",
    out_dir="/Users/kylamonique/Desktop/JPLFiles/data/SD"
)

process_site(
    site_name="PV",
    polygon_path="/Users/kylamonique/Desktop/JPLFiles/SpectralEvolution/GIS/Waypoints/PVQuadrat.geojson",
    out_dir="/Users/kylamonique/Desktop/JPLFiles/data/PV"
)
# Out:
#  Date range searched: 2024-01-01 to 2025-07-23
# 🔍 LCDM search:
#    ECOSTRESS granules found: 282
#    EMIT granules found:     12
#    Total granules found:     294
# ✅ LCDM: Found 882 granule files. Saved to /Users/kylamonique/Desktop/JPLFiles/data/LCDM
#  Date range searched: 2024-01-01 to 2025-07-23
# 🔍 SD search:
#    ECOSTRESS granules found: 255
#    EMIT granules found:     11
#    Total granules found:     266
# ✅ SD: Found 798 granule files. Saved to /Users/kylamonique/Desktop/JPLFiles/data/SD
#  Date range searched: 2024-01-01 to 2025-07-23
# 🔍 PV search:
#    ECOSTRESS granules found: 268
#    EMIT granules found:     8
#    Total granules found:     276
# ✅ PV: Found 828 granule files. Saved to /Users/kylamonique/Desktop/JPLFiles/data/PV
# ([Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-01-01T07:58:34.636Z', 'EndingDateTime': '2024-01-01T07:59:26.606Z'}}
#   Size(MB): 2.56
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01/ECOv002_L2T_LSTE_31117_001_11SLT_20240101T075834_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-01-02T07:10:24.942Z', 'EndingDateTime': '2024-01-02T07:11:16.912Z'}}
#   Size(MB): 2.9
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01/ECOv002_L2T_LSTE_31132_001_11SLT_20240102T071024_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-01-03T14:29:44.765Z', 'EndingDateTime': '2024-01-03T14:30:36.736Z'}}
#   Size(MB): 4.92
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01/ECOv002_L2T_LSTE_31152_002_11SLT_20240103T142944_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-01-05T06:21:36.321Z', 'EndingDateTime': '2024-01-05T06:22:28.290Z'}}
#   Size(MB): 11.21
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01_EmisWB.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01/ECOv002_L2T_LSTE_31178_001_11SLT_20240105T062136_0711_01_LST_err.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-01-06T05:32:58.264Z', 'EndingDateTime': '2024-01-06T05:33:50.234Z'}}
#   Size(MB): 0.37
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01_EmisWB.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01/ECOv002_L2T_LSTE_31193_001_11SLT_20240106T053258_0711_01_LST.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-01-06T13:41:49.097Z', 'EndingDateTime': '2024-01-06T13:42:41.066Z'}}
#   Size(MB): 9.43
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01/ECOv002_L2T_LSTE_31198_006_11SLT_20240106T134149_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-01-09T04:44:18.867Z', 'EndingDateTime': '2024-01-09T04:45:10.837Z'}}
#   Size(MB): 10.3
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01/ECOv002_L2T_LSTE_31239_002_11SLT_20240109T044418_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-01-14T10:27:26.174Z', 'EndingDateTime': '2024-01-14T10:28:18.144Z'}}
#   Size(MB): 6.73
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01/ECOv002_L2T_LSTE_31320_013_11SLT_20240114T102726_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-01-14T10:28:18.144Z', 'EndingDateTime': '2024-01-14T10:29:10.114Z'}}
#   Size(MB): 7.18
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01/ECOv002_L2T_LSTE_31320_014_11SLT_20240114T102818_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-01-17T01:32:29.323Z', 'EndingDateTime': '2024-01-17T01:33:21.292Z'}}
#   Size(MB): 10.71
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01/ECOv002_L2T_LSTE_31361_005_11SLT_20240117T013229_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-02-10T23:21:41.823Z', 'EndingDateTime': '2024-02-10T23:22:33.792Z'}}
#   Size(MB): 17.16
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01/ECOv002_L2T_LSTE_31747_013_11SLT_20240210T232141_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-03-11T04:02:12.037Z', 'EndingDateTime': '2024-03-11T04:03:04.006Z'}}
#   Size(MB): 10.59
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01_EmisWB.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01/ECOv002_L2T_LSTE_32200_005_11SLT_20240311T040212_0711_01_LST_err.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-03-12T11:22:28.578Z', 'EndingDateTime': '2024-03-12T11:23:20.548Z'}}
#   Size(MB): 2.38
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02/ECOv002_L2T_LSTE_32220_013_11SLT_20240312T112228_0711_02_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-03-18T01:40:49.605Z', 'EndingDateTime': '2024-03-18T01:41:41.575Z'}}
#   Size(MB): 3.11
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01_EmisWB.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01/ECOv002_L2T_LSTE_32307_003_11SLT_20240318T014049_0711_01_LST_err.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-04-02T19:20:52.439Z', 'EndingDateTime': '2024-04-02T19:21:44.409Z'}}
#   Size(MB): 0.75
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01/ECOv002_L2T_LSTE_32551_004_11SLT_20240402T192052_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-04-02T19:21:44.408Z', 'EndingDateTime': '2024-04-02T19:22:36.378Z'}}
#   Size(MB): 15.55
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01/ECOv002_L2T_LSTE_32551_005_11SLT_20240402T192144_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-04-06T17:45:04.077Z', 'EndingDateTime': '2024-04-06T17:45:56.047Z'}}
#   Size(MB): 17.47
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01/ECOv002_L2T_LSTE_32612_004_11SLT_20240406T174503_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-04-08T01:04:44.947Z', 'EndingDateTime': '2024-04-08T01:05:36.916Z'}}
#   Size(MB): 1.06
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01_EmisWB.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01/ECOv002_L2T_LSTE_32632_016_11SLT_20240408T010444_0711_01_LST_err.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-04-08T01:05:36.917Z', 'EndingDateTime': '2024-04-08T01:06:28.886Z'}}
#   Size(MB): 6.43
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01_EmisWB.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01/ECOv002_L2T_LSTE_32632_017_11SLT_20240408T010536_0711_01_LST_err.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-04-09T00:16:31.942Z', 'EndingDateTime': '2024-04-09T00:17:23.911Z'}}
#   Size(MB): 11.68
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01/ECOv002_L2T_LSTE_32647_012_11SLT_20240409T001631_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-04-09T00:17:23.912Z', 'EndingDateTime': '2024-04-09T00:18:15.881Z'}}
#   Size(MB): 1.34
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01/ECOv002_L2T_LSTE_32647_013_11SLT_20240409T001723_0711_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-04-11T23:28:30.549Z', 'EndingDateTime': '2024-04-11T23:29:22.518Z'}}
#   Size(MB): 16.79
# ...
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2025-07-14T02:04:31.396Z', 'EndingDateTime': '2025-07-14T02:05:23.366Z'}}
#   Size(MB): 17.64
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01/ECOv002_L2T_LSTE_39806_004_11SLT_20250714T020431_0713_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2025-07-18T00:26:31.526Z', 'EndingDateTime': '2025-07-18T00:27:23.497Z'}}
#   Size(MB): 16.09
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01/ECOv002_L2T_LSTE_39867_003_11SLT_20250718T002631_0713_01_EmisWB.tif'],
#   Collection: {'ShortName': 'ECO_L2T_LSTE', 'Version': '002'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -119.17378006048253, 'EastBoundingCoordinate': -117.96980924294873, 'NorthBoundingCoordinate': 34.33773312439149, 'SouthBoundingCoordinate': 33.33312764840095}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2025-07-20T23:38:12.192Z', 'EndingDateTime': '2025-07-20T23:39:04.162Z'}}
#   Size(MB): 6.21
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01_water.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01_cloud.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01_view_zenith.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01_height.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01_QC.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01_LST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01_LST_err.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2T_LSTE.002/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01/ECOv002_L2T_LSTE_39913_005_11SLT_20250720T233812_0713_01_EmisWB.tif']],
#  [Collection: {'ShortName': 'EMITL2ARFL', 'Version': '001'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -118.86822509765625, 'Latitude': 34.405914306640625}, {'Longitude': -119.36766052246094, 'Latitude': 33.790122985839844}, {'Longitude': -118.69038391113281, 'Latitude': 33.240821838378906}, {'Longitude': -118.19094848632812, 'Latitude': 33.85661315917969}, {'Longitude': -118.86822509765625, 'Latitude': 34.405914306640625}]}}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-04-19T20:13:05Z', 'EndingDateTime': '2024-04-19T20:13:17Z'}}
#   Size(MB): 3576.1988735198975
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240419T201305_2411013_008/EMIT_L2A_RFL_001_20240419T201305_2411013_008.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240419T201305_2411013_008/EMIT_L2A_RFLUNCERT_001_20240419T201305_2411013_008.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240419T201305_2411013_008/EMIT_L2A_MASK_001_20240419T201305_2411013_008.nc'],
#   Collection: {'ShortName': 'EMITL2ARFL', 'Version': '001'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -118.6656265258789, 'Latitude': 34.45540237426758}, {'Longitude': -119.17668914794922, 'Latitude': 33.82472610473633}, {'Longitude': -118.49983978271484, 'Latitude': 33.2762565612793}, {'Longitude': -117.98877716064453, 'Latitude': 33.90693283081055}, {'Longitude': -118.6656265258789, 'Latitude': 34.45540237426758}]}}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-21T19:14:44Z', 'EndingDateTime': '2024-06-21T19:14:55Z'}}
#   Size(MB): 3579.3668394088745
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240621T191444_2417313_007/EMIT_L2A_RFL_001_20240621T191444_2417313_007.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240621T191444_2417313_007/EMIT_L2A_RFLUNCERT_001_20240621T191444_2417313_007.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240621T191444_2417313_007/EMIT_L2A_MASK_001_20240621T191444_2417313_007.nc'],
#   Collection: {'ShortName': 'EMITL2ARFL', 'Version': '001'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -118.5838394165039, 'Latitude': 34.781700134277344}, {'Longitude': -119.08666229248047, 'Latitude': 34.15043640136719}, {'Longitude': -118.39795684814453, 'Latitude': 33.60185241699219}, {'Longitude': -117.89513397216797, 'Latitude': 34.233116149902344}, {'Longitude': -118.5838394165039, 'Latitude': 34.781700134277344}]}}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-25T17:39:07Z', 'EndingDateTime': '2024-06-25T17:39:19Z'}}
#   Size(MB): 3580.64870262146
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240625T173907_2417712_009/EMIT_L2A_RFL_001_20240625T173907_2417712_009.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240625T173907_2417712_009/EMIT_L2A_RFLUNCERT_001_20240625T173907_2417712_009.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240625T173907_2417712_009/EMIT_L2A_MASK_001_20240625T173907_2417712_009.nc'],
#   Collection: {'ShortName': 'EMITL2ARFL', 'Version': '001'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -118.42867279052734, 'Latitude': 34.42942428588867}, {'Longitude': -118.93482208251953, 'Latitude': 33.80508041381836}, {'Longitude': -118.25740814208984, 'Latitude': 33.25590896606445}, {'Longitude': -117.75125885009766, 'Latitude': 33.880252838134766}, {'Longitude': -118.42867279052734, 'Latitude': 34.42942428588867}]}}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-08-25T17:31:15Z', 'EndingDateTime': '2024-08-25T17:31:27Z'}}
#   Size(MB): 3579.4814462661743
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240825T173115_2423811_008/EMIT_L2A_RFL_001_20240825T173115_2423811_008.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240825T173115_2423811_008/EMIT_L2A_RFLUNCERT_001_20240825T173115_2423811_008.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20240825T173115_2423811_008/EMIT_L2A_MASK_001_20240825T173115_2423811_008.nc'],
#   Collection: {'ShortName': 'EMITL2ARFL', 'Version': '001'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -118.55077362060547, 'Latitude': 34.642295837402344}, {'Longitude': -119.3215560913086, 'Latitude': 34.02610778808594}, {'Longitude': -118.82703399658203, 'Latitude': 33.40751647949219}, {'Longitude': -118.0562515258789, 'Latitude': 34.023704528808594}, {'Longitude': -118.55077362060547, 'Latitude': 34.642295837402344}]}}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2025-03-24T22:09:53Z', 'EndingDateTime': '2025-03-24T22:10:05Z'}}
#   Size(MB): 3579.960346221924
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250324T220953_2508314_003/EMIT_L2A_RFL_001_20250324T220953_2508314_003.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250324T220953_2508314_003/EMIT_L2A_RFLUNCERT_001_20250324T220953_2508314_003.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250324T220953_2508314_003/EMIT_L2A_MASK_001_20250324T220953_2508314_003.nc'],
#   Collection: {'ShortName': 'EMITL2ARFL', 'Version': '001'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -118.42823791503906, 'Latitude': 34.02879333496094}, {'Longitude': -119.193115234375, 'Latitude': 33.41261291503906}, {'Longitude': -118.69830322265625, 'Latitude': 32.79838562011719}, {'Longitude': -117.93342590332031, 'Latitude': 33.41456604003906}, {'Longitude': -118.42823791503906, 'Latitude': 34.02879333496094}]}}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2025-03-28T20:32:33Z', 'EndingDateTime': '2025-03-28T20:32:45Z'}}
#   Size(MB): 3577.8096923828125
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250328T203233_2508713_003/EMIT_L2A_RFL_001_20250328T203233_2508713_003.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250328T203233_2508713_003/EMIT_L2A_RFLUNCERT_001_20250328T203233_2508713_003.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250328T203233_2508713_003/EMIT_L2A_MASK_001_20250328T203233_2508713_003.nc'],
#   Collection: {'ShortName': 'EMITL2ARFL', 'Version': '001'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -117.79301452636719, 'Latitude': 34.5408821105957}, {'Longitude': -118.55767822265625, 'Latitude': 33.923641204833984}, {'Longitude': -118.06092834472656, 'Latitude': 33.308231353759766}, {'Longitude': -117.2962646484375, 'Latitude': 33.925472259521484}, {'Longitude': -117.79301452636719, 'Latitude': 34.5408821105957}]}}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2025-03-28T20:32:45Z', 'EndingDateTime': '2025-03-28T20:32:57Z'}}
#   Size(MB): 3577.1275272369385
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250328T203245_2508713_004/EMIT_L2A_RFL_001_20250328T203245_2508713_004.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250328T203245_2508713_004/EMIT_L2A_RFLUNCERT_001_20250328T203245_2508713_004.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250328T203245_2508713_004/EMIT_L2A_MASK_001_20250328T203245_2508713_004.nc'],
#   Collection: {'ShortName': 'EMITL2ARFL', 'Version': '001'}
#   Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -118.26221466064453, 'Latitude': 34.264034271240234}, {'Longitude': -119.0237808227539, 'Latitude': 33.64518356323242}, {'Longitude': -118.51824188232422, 'Latitude': 33.023075103759766}, {'Longitude': -117.75667572021484, 'Latitude': 33.64192581176758}, {'Longitude': -118.26221466064453, 'Latitude': 34.264034271240234}]}}]}}}
#   Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2025-05-25T21:34:43Z', 'EndingDateTime': '2025-05-25T21:34:55Z'}}
#   Size(MB): 3578.239049911499
#   Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250525T213443_2514514_003/EMIT_L2A_RFL_001_20250525T213443_2514514_003.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250525T213443_2514514_003/EMIT_L2A_RFLUNCERT_001_20250525T213443_2514514_003.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250525T213443_2514514_003/EMIT_L2A_MASK_001_20250525T213443_2514514_003.nc']])

# %%
import geopandas as gpd
import earthaccess

# Load ROI
poi = gpd.read_file("/Users/kylamonique/Desktop/JPLFiles/SpectralEvolution/GIS/Waypoints/LCDMQuadrat.geojson")
minx, miny, maxx, maxy = poi.total_bounds

# Date range
date_range = ("2025-04-01", "2025-05-31")

# Swath concept IDs
concept_ids = [
    "C2408750690-LPCLOUD",   # EMIT L2A Reflectance (swath)
    "C2076114664-LPCLOUD"    # ECOSTRESS L2 Swath LSTE :contentReference[oaicite:1]{index=1}
]

# Search swath granules
swath_results = earthaccess.search_data(
    concept_id=concept_ids,
    bounding_box=(minx, miny, maxx, maxy),
    temporal=date_range,
    cloud_hosted=True
)

# Separate swath products
emit_swath = [g for g in swath_results if g["umm"]["CollectionReference"]["ShortName"].startswith("EMIT")]
eco_swath  = [g for g in swath_results if g["umm"]["CollectionReference"]["ShortName"].startswith("ECO_L2_LSTE")]

print(f"Swath granules total: {len(swath_results)}")
print(f"EMIT swath granules: {len(emit_swath)}")
print(f"ECOSTRESS swath granules: {len(eco_swath)}")

# Write swath asset URLs to file
output = "swath_granules.txt"
with open(output, "w") as f:
    for g in swath_results:
        for url in g.data_links(access="https"):
            if url.endswith(('.nc', '.h5', '.hdf5')):
                f.write(url + "\n")

print(f"✅ Swath granule links saved to {output}")
# Out:
# Swath granules total: 41
# EMIT swath granules: 5
# ECOSTRESS swath granules: 36
# ✅ Swath granule links saved to swath_granules.txt

# %% [markdown]
# Manually input lat and lon locations

# %%
import os
import pandas as pd
import earthaccess

def process_site_from_bbox(site_name, bounding_box, out_dir, start_date="2024-01-01", end_date="2025-06-30", save_results=True):
    """
    For a given site:
    - Searches ECOSTRESS and EMIT granules using manually input bounding box
    - Filters to relevant file types
    - Optionally saves result URLs in a .txt file
    """

    # Unpack bounding box
    min_lon, min_lat, max_lon, max_lat = bounding_box
    print(f"\n Searching site: '{site_name}'")
    print(f" Bounding Box: Lon [{min_lon}, {max_lon}], Lat [{min_lat}, {max_lat}]")
    print(f" Date Range: {start_date} to {end_date}")

    # Earthdata concept IDs
    concept_ids = [
        "C2408750690-LPCLOUD",  # EMIT L2A Reflectance (swath)
        "C2076114664-LPCLOUD"   # ECOSTRESS L2 Swath LSTE
    ]

    # Perform search
    swath_results = earthaccess.search_data(
        concept_id=concept_ids,
        bounding_box=(min_lon, min_lat, max_lon, max_lat),
        temporal=(start_date, end_date),
        cloud_hosted=True
    )

    print(f" Total granules found: {len(swath_results)}")

    # Filter granules by mission
    emit_granules = [g for g in swath_results if g["umm"]["CollectionReference"]["ShortName"].startswith("EMIT")]
    eco_granules  = [g for g in swath_results if g["umm"]["CollectionReference"]["ShortName"].startswith("ECO_L2")]

    # Define desired file extensions
    desired_ecostress_ext = ['.h5', '.nc', '.hdf5']
    desired_emit_ext = ['.nc']

    # Extract URLs
    filtered_urls = []
    for g in eco_granules:
        for url in g.data_links(access="https"):
            if any(url.endswith(ext) for ext in desired_ecostress_ext):
                filtered_urls.append(url)
    for g in emit_granules:
        for url in g.data_links(access="https"):
            if any(url.endswith(ext) for ext in desired_emit_ext):
                filtered_urls.append(url)

    # Save results to file
    if save_results:
        os.makedirs(out_dir, exist_ok=True)
        txt_path = os.path.join(out_dir, f"{site_name}_granules.txt")
        with open(txt_path, "w") as f:
            for url in filtered_urls:
                f.write(url + "\n")
        print(f"📁 Saved granule URLs to: {txt_path}")

    # Summary
    print(f"\n {site_name} Summary:")
    print(f"   ECOSTRESS granules: {len(eco_granules)}")
    print(f"   EMIT granules:     {len(emit_granules)}")
    print(f"   Filtered URLs:     {len(filtered_urls)}")

    return eco_granules, emit_granules
